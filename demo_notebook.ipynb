# %%
from crawler import crawler

# %%
crawler = crawler()

# %%
crawler.crawl_directory_url('https://www.cs.rutgers.edu')
# Out:
# ['https://www.cs.rutgers.edu/people/professors',
#  'https://www.cs.rutgers.edu/people/professors/details',
#  'https://www.cs.rutgers.edu/people/part-time-lecturers',
#  'https://www.cs.rutgers.edu/people/researchers',
#  'https://www.cs.rutgers.edu/people/staff',
#  'https://www.cs.rutgers.edu/people/staff/details',
#  'https://www.cs.rutgers.edu/people/graduate-students',
#  'https://www.cs.rutgers.edu/people/graduate-students/details',
#  'https://www.cs.rutgers.edu/people/emeritus',
#  'https://www.cs.rutgers.edu/people/alumni',
#  'https://www.cs.rutgers.edu/people/alumni/details',
#  'https://www.cs.rutgers.edu/people/distinguished-alumni']

# %%
crawler.crawl_faculty_url('https://www.cs.rutgers.edu', 'https://www.cs.rutgers.edu/people/professors')
# Out:
# ['https://www.cs.rutgers.edu/people/professors/details',
#  'https://www.cs.rutgers.edu/people/part-time-lecturers',
#  'https://www.cs.rutgers.edu/people/affiliated-faculty',
#  'https://www.cs.rutgers.edu/people/researchers',
#  'https://www.cs.rutgers.edu/people/staff',
#  'https://www.cs.rutgers.edu/people/staff/details',
#  'https://www.cs.rutgers.edu/people/graduate-students',
#  'https://www.cs.rutgers.edu/people/graduate-students/details',
#  'https://www.cs.rutgers.edu/people/technical-staff',
#  'https://www.cs.rutgers.edu/people/emeritus',
#  'https://www.cs.rutgers.edu/people/alumni',
#  'https://www.cs.rutgers.edu/people/alumni/details',
#  'https://www.cs.rutgers.edu/people/distinguished-alumni',
#  'https://www.cs.rutgers.edu/news-events/cs-events/research-faculty-candidate-talks/range.listevents/-',
#  'https://www.cs.rutgers.edu/people/professors/articles?filter-match=any&tmpl=component&print=1&start=0',
# ...

# %%
crawler.crawl('https://www.cs.rutgers.edu')
# Out:
# ['https://www.cs.rutgers.edu/people/professors/details',
#  'https://www.cs.rutgers.edu/people/part-time-lecturers',
#  'https://www.cs.rutgers.edu/people/affiliated-faculty',
#  'https://www.cs.rutgers.edu/people/researchers',
#  'https://www.cs.rutgers.edu/people/staff',
#  'https://www.cs.rutgers.edu/people/staff/details',
#  'https://www.cs.rutgers.edu/people/graduate-students',
#  'https://www.cs.rutgers.edu/people/graduate-students/details',
#  'https://www.cs.rutgers.edu/people/technical-staff',
#  'https://www.cs.rutgers.edu/people/emeritus',
#  'https://www.cs.rutgers.edu/people/alumni',
#  'https://www.cs.rutgers.edu/people/alumni/details',
#  'https://www.cs.rutgers.edu/people/distinguished-alumni',
#  'https://www.cs.rutgers.edu/news-events/cs-events/research-faculty-candidate-talks/range.listevents/-',
#  'https://www.cs.rutgers.edu/people/professors/articles?filter-match=any&tmpl=component&print=1&start=0',
# ...
